# %%
import numpy as np
import pandas as pd
import matplotlib as mp 
import seaborn as sns

# %%
df = pd.read_csv('house_pricing.csv')

# %%
mp.pyplot.subplots(figsize=(20,15))
heatmap = sns.heatmap(df[(df.columns[-15:])].corr(), annot=True)
